# %% [markdown]
# ## Optimización
#
# En este notebook, presentamos optimizacion de inventario y fuerza de ventas.
#
# - Surtido y compra: top categorías por temporada/zonas y semanas de cobertura
# sugeridas.
# - Operación: reasignación de inventario, ventanas de mantenimiento/descanso.
# - Comercial: promociones por clúster/temporada; alertas tempranas de quiebre.
